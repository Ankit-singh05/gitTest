# %%
raw_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/demo_catalog/delta_test/filestore/orders_dataset.csv")

raw_df.display()

# %%
raw_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/demo_catalog/delta_test/filestore/products_dataset.csv")

raw_df.display()

# %%
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta/bronze")
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta/silver")
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta/gold")

# %%
raw_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/Volumes/demo_catalog/delta_test/filestore/products_dataset.csv")

# %%
bronze_df = spark.read.format("delta").load("/Workspace/Users/ankitsingh231225@gmail.com/delta/bronze/order_data")
bronze_df.display()
