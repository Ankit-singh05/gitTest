# %%
data = [
    (1, "Ankit", "Laptop", 50000),
    (2, "Rahul", "Mobile", 20000),
    (3, "Neha", "Tablet", 30000)
]

columns = ["order_id", "customer", "product", "amount"]

df = spark.createDataFrame(data, columns)
df.display()

# %%
# %sql
SHOW VOLUMES

# %%
display(_sqldf)

# %%
df.write.format("delta") \
  .mode("overwrite") \
  .save("/Volumes/demo_catalog/delta_test/orders_delta")
