# %%
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta_test")
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta_test/bronze")
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta_test/silver")
dbutils.fs.mkdirs("/Workspace/Users/ankitsingh231225@gmail.com/delta_test/gold")

# %%
raw_data = [
    (1, "Alice", "Engineering", "75000"),
    (2, "Bob", "Sales", "65000"),
    (3, "Alice", "Engineering", "75000"),  # duplicate
    (4, "Diana", "HR", None)
]

columns = ["employee_id", "name", "department", "salary"]

raw_df = spark.createDataFrame(raw_data, columns)
raw_df.display()

# %%
raw_df.write \
  .format("delta") \
  .mode("overwrite") \
  .save("dbfs:/delta_test/bronze/employees")
